# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip3 install seaborn==0.9.0
# Out:
#   File "<ipython-input-2-9600b5c5940f>", line 1
#     pip3 install seaborn==0.9.0
#                ^
# SyntaxError: invalid syntax

# %%
pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
# %matplotlib inline

# %%
# !pip install --user scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
# %matplotlib inline

# %%
# %%bash
# which python

# %%
pip install --pre -f https://sklearn-nightly.scdn8.secure.raxcdn.com scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline

# %%
pip install -U scikit-learn scipy matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline

# %%
 python
import sklearn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
jupyter kernel spec list

# %%
import pandas as pd
from sklearn import tree # tree scope contains the classifier

# then in the code, access the DecisionTreeClassifier like, 
model = tree.DecisionTreeClassifier()

# %%
pip install --exists-action=i scikit-learn

# %%
conda install -c pchrapka scikit-feature

# %%
pip install -U scikit-learn
from sklearn.pipeline import Pipeline

# %%
pip install numpy

# %%
pip install Scipy

# %%
pip install sklearn

# %%
import sklearn

# %%
pip install -U scikit-learn

# %%
python -m pip show scikit-learn

# %%
python -c "import sklearn; sklearn.show_versions()"

# %%
sudo port install py36-scikit-learn

# %%
pip install --exists-action=i scikit-learn

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn import svm
from sklearn.datasets import make_classification
from sklearn.pipeline import Pipeline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
# %matplotlib inline

# %%
file_name='\users\vinaybhore\Downloads\Kc-house-data.csv'

# %%
df = pd.read_csv('Kc_house_data.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
# %matplotlib inline

df = pd.read_csv('Kc-house-data.csv')
df.head()

# %%
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)

# %%
requests.get('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv', verify=False)

# %%
 pip install -U requests[security]

# %%
pip install -U requests[security] --no-cache
pip install -U requests[security] --no-cache

# %%
pip install certifi==2015.04.28

# %%
pip install --upgrade pip

# %%
file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
# %matplotlib inline

# %%
file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)

# %%
pip install --upgrade certifi

# %%
file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)

# %%
 Install Certificates.command

# %%
cd /Applications/Python\ 3.6/

# %%
/Applications/Python\ 3.6/Install\ Certificates.command

# %%
 sudo update-ca-certificates --fresh
 export SSL_CERT_DIR=/etc/ssl/certs

# %%
pip3 install urllib3==1.24.3

# %%
pip3 uninstall urllib3

# %%
brew link python3

# %%
file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN(2).csv'
df=pd.read_csv(file_name)

# %%
import requests

# %%
pip --cert /Users/user/cacert.pem install -U channels

# %%
pip config --set ssl_verify false

# %%
pip install Pillow --trusted-host pypi.python.org --index-url=http://pypi.python.org/simple/

# %%
pip install -U certifi

# %%
SSL_CERT_FILE=path/to/ssl/certificate/file jupyter notebook

# %%
    x = requests.get(url=url, certs= certs).content 
    pd.read_csv(io.StringIO(x.decode('utf8')))

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
# importing the data
file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)
df.head()

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show,output_notebook
output_notebook()

# %%
urllib.request.urlopen('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv').read()

# %%
from urllib.request import urlopen
urllib.request.urlopen('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv').read()

# %%
python setup.py install

# %%
py -m pip install requests

# %%
import requests
from urllib3.exceptions import InsecureRequestWarning


old_merge_environment_settings = requests.Session.merge_environment_settings

@contextlib.contextmanager
def no_ssl_verification():
    opened_adapters = set()

# %%
conda install requests

# %%
from io import StringIO

import pandas as pd
import requests
url='https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'
s=requests.get(url).text

c=pd.read_csv(StringIO(s))

# %%
    url='https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'

# %%
import pandas as pd
url='https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'

# %%
import pandas as pd
train = pd.read_table(r"https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv")
train.head()

# %%
url = "https://github.com/cs109/2014_data/blob/master/countries.csv"
c = pd.read_csv(url, sep = "\t")

# %%
pd.read_csv('C:\Users\user\Desktop\Workbook1.csv')

# %%
import pandas as pd
import numpy as np

# %%
from pandas import read_csv

# %%
from pandas import read_csv
data = read_csv("C:/Users/vinaybhore/Downloads/kc_house_data_NaN (2)")

# %%
import pandas

# %%
from pandas import read_csv
data = read_csv( ~Downloads/kc_house_data_NaN (2))

# %%
from sklearn.preprocessing import Imputer 
imputer= Imputer(missing_values='NaN', strategy='mean' , axis = 0) 
imputer.fit(dataset)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-49-bd4ac032b587> in <module>
# ----> 1 from sklearn.preprocessing import Imputer
#       2 imputer= Imputer(missing_values='NaN', strategy='mean' , axis = 0)
#       3 imputer.fit(dataset)
#
# ImportError: cannot import name 'Imputer' from 'sklearn.preprocessing' (/Users/vinaybhore/Library/Python/3.7/lib/python/site-packages/sklearn/preprocessing/__init__.py)

# %%
import pandas as pd

pd.read_csv(r'C:\Users\vinaybhore\Downloads\kc_house_data_NaN (2).csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn import preprocessing


from sklearn.preprocessing import LabelEncoder, MinMaxScaler
regr = LinearRegression()
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import  Lasso

      




from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib import style
from sklearn.decomposition import PCA
import matplotlib.cm as cm
from sklearn.preprocessing import PolynomialFeatures
from matplotlib import *

# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("C:/Users/vinaybhore/Downloads/Housingdata.csv",encoding = "utf-8")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-155-db8402e49bfb> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("C:/Users/vinaybhore/Downloads/Housingdata.csv",encoding = "utf-8")
#       3 df
#       4
#       5
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1872         if kwds.get("compression") is None and encoding:
#    1873             if isinstance(src, str):
# -> 1874                 src = open(src, "rb")
#    1875                 self.handles.append(src)
#    1876
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/vinaybhore/Downloads/Housingdata.csv'

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/Users/vinaybhore/Project/housing-data.csv')
print("student data read successfully ")
# Out:
# student data read successfully

# %%
df.head()
# Out:
#    Unnamed: 0          id             date   price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900       3.0       1.00
# 1           1  6414100192  20141209T000000  538000       3.0       2.25
# 2           2  5631500400  20150225T000000  180000       2.0       1.00
# 3           3  2487200875  20141209T000000  604000       4.0       3.00
# 4           4  1954400510  20150218T000000  510000       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 22 columns]

# %%
print (df.shape)
# Out:
# (21613, 22)

# %%
list(df.columns.values)
# Out:
# ['Unnamed: 0',
#  'id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
specifics = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','grade','sqft_above','sqft_basement','yr_built','yr_renovated','zipcode','lat','long','sqft_living15','sqft_lot15']

# %%
specifics_matrix = df[specifics]
#specifics_matrix = preprocessing.scale(specifics_matrix)
specifics_matrix_unscaled = df[specifics]
lable_vector = df['price']
specifics_matrix_unscaled.head()
#specifics_matrix[0::1000]
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       3.0       1.00         1180      5650     1.0           0     0
# 1       3.0       2.25         2570      7242     2.0           0     0
# 2       2.0       1.00          770     10000     1.0           0     0
# 3       4.0       3.00         1960      5000     1.0           0     0
# 4       3.0       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257           1340        5650
# 1    98125  47.7210 -122.319           1690        7639
# 2    98028  47.7379 -122.233           2720        8062
# 3    98136  47.5208 -122.393           1360        5000
# 4    98074  47.6168 -122.045           1800        7503

# %%
sns.set(font_scale=2.2)
str_list = [] # empty list to contain columns with strings (words)
for colname, colvalue in df.iteritems():
   if type(colvalue[1]) == str:
        str_list.append(colname)
# Get to the numeric columns by inversion            
num_list = df.columns.difference(str_list) 
# Create Dataframe containing only numerical features
house_num = df[num_list]
f, ax = plt.subplots(figsize=(35, 30))
plt.title('Correlation of features')
# Draw the heatmap using seaborn
#sns.heatmap(house_num.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="PuBuGn", linecolor='k', annot=True)
sns.heatmap(house_num.astype(float).corr(),linewidths=2.0,vmax=1.0, square=True, cmap="YlGnBu", linecolor='k', annot=True)
plt.show()

# %%
style.use('fivethirtyeight')
cm = plt.cm.get_cmap('RdYlBu')
xy = range(1,21614)
z = xy
for specifics in specifics_matrix_unscaled:
    sc = plt.scatter(df[specifics], df['price'], label = specifics, c = z, marker = 'o', s = 30, cmap = cm)
    plt.colorbar(sc)
    plt.xlabel(''+specifics)
    plt.ylabel('price')
    plt.yticks([0, 500000, 1000000, 1500000, 2000000, 2500000, 3000000, 3500000, 4000000, 4500000, 5000000, 5500000, 6000000, 6500000, 7000000, 7500000, 8000000],
            ['0', '0.5M', '1M', '1.5M', '2M', '2.5M', '3M',  '3.5M', '4M', '4.5M', '5M', '5.5M', '6M', '6.5M', '7M', '7.5M', '8M',])
    plt.legend()
    plt.show()

# %%
my_linear = LinearRegression()
my_linear.fit(specifics_matrix, lable_vector)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-3b9ad5841a06> in <module>
#       1 my_linear = LinearRegression()
# ----> 2 my_linear.fit(specifics_matrix, lable_vector)
#
# ~/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# ~/Library/Python/3.7/lib/python/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/Library/Python/3.7/lib/python/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# ~/Library/Python/3.7/lib/python/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(my_linear.intercept_)

# printing [Theta1, Theta2, Theta3] using attribute "coef_":
print(my_linear.coef_)
coef_list = my_linear.coef_
# coef_list.sort()
print(coef_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-22b9790854c3> in <module>
# ----> 1 print(my_linear.intercept_)
#       2
#       3 # printing [Theta1, Theta2, Theta3] using attribute "coef_":
#       4 print(my_linear.coef_)
#       5 coef_list = my_linear.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
print(df .isnull().any().sum(), '/',len(df.columns))
print(df.isnull().any().any(axis=1).sum(),'/',len(df))
# Out:
# 2 / 22
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-19a8e88a8e36> in <module>
#       1 print(df .isnull().any().sum(), '/',len(df.columns))
# ----> 2 print(df.isnull().any().any(axis=1).sum(),'/',len(df))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in logical_func(self, axis, bool_only, skipna, level, **kwargs)
#   11365             skipna=skipna,
#   11366             numeric_only=bool_only,
# > 11367             filter_type="bool",
#   11368         )
#   11369
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3867
#    3868         if axis is not None:
# -> 3869             self._get_axis_number(axis)
#    3870
#    3871         if isinstance(delegate, Categorical):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named 1 for object type <class 'pandas.core.series.Series'>

# %%
features = df.iloc[:,3:].columns.tolist()

# %%
target = df.iloc[:,2].name

# %%
sorted_features = ['grade','lat','sqft_living','sqft_above','waterfront','view']
sns.set(font_scale=2.2)
g = sns.pairplot(df[sorted_features] ,size=5)
plt.show()

# %%
#sorting best features based on co-efficient values.
#sorted_features = ['sqft_living','sqft_basement','sqft_above','sqft_lot','yr_built','bedrooms']
#sorted_features = ['lat','waterfront','grade','view','bathrooms','condition'] # all features without scale
sorted_features = ['grade','lat','sqft_living','sqft_above','waterfront','view']
best_feature_matrix = df[sorted_features]
#scaling deature
#best_feature_matrix = preprocessing.scale(best_feature_matrix)

X_train, X_test, y_train, y_test = train_test_split(best_feature_matrix, lable_vector, test_size=0.3, random_state=3)
my_linear.fit(X_train, y_train)
y_predict_ln = my_linear.predict(X_test)
print(y_predict_ln)
# Out:
# [ 603611.88117219 1101117.79721372  833606.46564271 ...  205362.38746914
#   364435.62431653  356653.0872076 ]

# %%
y_predict_ln = my_linear.predict(X_test)
fig, ax = plt.subplots()
ax.scatter(y_test, y_predict_ln, edgecolors=(0, 0, 0))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
error = mean_squared_error(y_test, y_predict_ln)
root_mean_square_error = np.sqrt(error)
print("RMSE for liner regression>>>",root_mean_square_error)
# Out:
# RMSE for liner regression>>> 213098.2225629482

# %%
k = 25
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
y_predict_knn = knn.predict(X_test)
score_knn = accuracy_score(y_test, y_predict_knn)
print("KNN accuracy>>>>",score_knn)
# Out:
# KNN accuracy>>>> 0.005243676742751388

# %%
my_decisiontree = DecisionTreeClassifier()
my_decisiontree.fit(X_train, y_train)
y_predict_dt = my_decisiontree.predict(X_test)
score_dt= accuracy_score(y_test, y_predict_dt)
print("Decision tree accuracy>>>>",score_dt)
# Out:
# Decision tree accuracy>>>> 0.007248611967921036

# %%
kc_linear_reg = LinearRegression()
new_feature_marrix = preprocessing.scale(feature_matrix)
kc_mse = cross_val_score(kc_linear_reg,new_feature_marrix,lable_vector, cv=10, scoring='neg_mean_squared_error')


house_mse_positive = -kc_mse

house_rmse = np.sqrt(house_mse_positive)

print("RMSE for cross validation>>>",house_rmse.mean())
# Out:
# RMSE for cross validation>>> nan

# %%
my_RandomForest = RandomForestClassifier(n_estimators = 10, bootstrap = True, random_state=2)
my_RandomForest.fit(X_train,y_train) #train random forest classifier using training data
y_predict_rf=my_RandomForest.predict(X_test) #predict using testing data
score_rf=accuracy_score(y_test, y_predict_rf) #accuracy based on predicted values and original values
print("Accuracy for Random Forest>>>>> ",score_rf)
# Out:
# Accuracy for Random Forest>>>>>  0.010333127698951264

# %%
n=6
my_pca = PCA(n_components=n)
feature_matrix_scaled = preprocessing.scale(feature_matrix)
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(feature_matrix_scaled, lable_vector, test_size=0.3, random_state=3)

# %%
#Adding features by taking square of each feature.

# %%
df.square = pd.DataFrame()
for feature in features:
    df.square[feature + '_square'] = df[feature]*df[feature]
print(df.shape)
# Out:
# (21613, 23)

# %%
square_df = pd.concat([specifics_matrix_unscaled, df.square], axis=1)
square_df.shape
# Out:
# (21613, 37)

# %%
#normalize data
scaled_square_df = preprocessing.scale(square_df)

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.fit_transform(X_test)
#print(X_train_poly.shape)
poly_lin_reg = LinearRegression()
poly_lin_reg.fit(X_train_poly, y_train)
y_predict_poly = poly_lin_reg.predict(X_test_poly)
print(y_predict_poly)
# Out:
# [ 542076.15477657 1149612.90509605  813266.00861263 ...  285320.66978264
#   288119.67642307  360417.51964092]

# %%
error = mean_squared_error(y_predict_poly, y_test)
#print(error)
root_mean_square_error = np.sqrt(error)
print("RMSE for polynomial regression>>>>>>>>",root_mean_square_error)
# Out:
# RMSE for polynomial regression>>>>>>>> 184575.08418778112

# %%
z = np.polyfit(y_test,y_predict_poly,10) 

p = np.poly1d(z)

plt.title ('Polynomial Regression')
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.yticks([0, 500000, 1000000, 1500000, 2000000, 2500000, 3000000, 3500000, 4000000, 4500000, 5000000, 5500000, 6000000, 6500000, 7000000, 7500000, 8000000],
            ['0', '0.5M', '1M', '1.5M', '2M', '2.5M', '3M',  '3.5M', '4M', '4.5M', '5M', '5.5M', '6M', '6.5M', '7M', '7.5M', '8M'], fontsize = 12)
plt.xticks([0, 500000, 1000000, 1500000, 2000000, 2500000, 3000000, 3500000, 4000000, 4500000, 5000000, 5500000, 6000000, 6500000, 7000000, 7500000, 8000000],
            ['0', '0.5M', '1M', '1.5M', '2M', '2.5M', '3M',  '3.5M', '4M', '4.5M', '5M', '5.5M', '6M', '6.5M', '7M', '7.5M', '8M'], fontsize = 12)
    

#plt.plot(y_test[:100], y_predict_poly[:100],'o-')
#plt.plot(y_test[:5], y_predict_poly[:5], '-')

datax_os = np.linspace(y_test.min(), y_test.max(), 50)
#plt.figure(figsize=(18,18))
plt.plot(y_test, y_predict_poly, 'o',datax_os, p(datax_os) ) # 'smoother' line

plt.show()

# %%
specifics=df.values

# %%
specifics
# Out:
# array([[0, 7129300520, '20141013T000000', ..., 1340, 5650, 2014],
#        [1, 6414100192, '20141209T000000', ..., 1690, 7639, 2014],
#        [2, 5631500400, '20150225T000000', ..., 2720, 8062, 2015],
#        ...,
#        [21610, 1523300141, '20140623T000000', ..., 1020, 2007, 2014],
#        [21611, 291310100, '20150116T000000', ..., 1410, 1287, 2015],
#        [21612, 1523300157, '20141015T000000', ..., 1020, 1357, 2014]],
#       dtype=object)

# %%
X = specifics[:,0:10]

# %%
Y = specifics[:,10]

# %%
df['price'].describe()
df['price']=df['price']
#histogram
sns.distplot(df['price'], bins=50, kde=False);

# %%
print("Skewness: %f" % df['price'].skew())
print("Kurtosis: %f" % df['price'].kurt())
# Out:
# Skewness: 4.024069
# Kurtosis: 34.585540

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                Total   Percent
# bedrooms          13  0.000601
# bathrooms         10  0.000463
# year_sell          0  0.000000
# view               0  0.000000
# id                 0  0.000000
# date               0  0.000000
# price              0  0.000000
# sqft_living        0  0.000000
# sqft_lot           0  0.000000
# floors             0  0.000000
# waterfront         0  0.000000
# condition          0  0.000000
# sqft_lot15         0  0.000000
# grade              0  0.000000
# sqft_above         0  0.000000
# sqft_basement      0  0.000000
# yr_built           0  0.000000
# yr_renovated       0  0.000000
# zipcode            0  0.000000
# lat                0  0.000000

# %%
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# price              int64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# year_sell          int64
# dtype: object

# %%
corr = numeric_features.corr()
print (corr['price'].sort_values(ascending=False)[:5], '\n')
print (corr['price'].sort_values(ascending=False)[-5:])
# Out:
# price            1.000000
# sqft_living      0.712431
# grade            0.670163
# sqft_above       0.616306
# sqft_living15    0.583507
# Name: price, dtype: float64
#
# Unnamed: 0    0.026452
# long          0.023589
# id           -0.021333
# zipcode      -0.052022
# year_sell          NaN
# Name: price, dtype: float64

# %%
df.columns = df.columns.str.strip()

# %%
#wrangaling the non numeric feature

# %%
categoricals = df.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
#lasso regression
